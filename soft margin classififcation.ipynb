# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC

# %%
# load the data set

X, y = datasets.make_classification(
    n_samples = 100,
    n_features = 2,
    n_informative = 2,
    n_redundant = 0,
    n_clusters_per_class=1,
    flip_y = 0.1,
    class_sep = 1.0,
    random_state = 42
)

# %%
# Change labels from (0.1) to (-1,1) for better understanding
y = np.where(y == 0 , -1 , 1)

# %%
# Train a soft Margin SVM ( default is soft )
clf = SVC(kernel = 'linear' , C=1.0) # Try C = 0.1 or C = 100 to see the effect
clf.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
# Plotting the decision boundary
def plot_svm(clf , X, y):
    plt.scatter(X[:,0],X[:,1],c=y,cmap='bwr', s=300)

    ax = plt.gca()
    xlim = ax.get_xlime()
    ylim = ax.get_ylim()

# %%
# Create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1],
           alpha=0.5, linestyles=['--', '-', '--'])

# Plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
           s=100, linewidth=1, facecolors='none', edgecolors='k')

plt.title("Soft Margin SVM with C = {}".format(clf.C))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Create grid to evaluate model
# ----> 2 xx = np.linspace(xlim[0], xlim[1], 30)
#       3 yy = np.linspace(ylim[0], ylim[1], 30)
#       4 YY, XX = np.meshgrid(yy, xx)
#
# NameError: name 'xlim' is not defined

# %% [raw]
# Try Playing With:
# C=0.1 (loose margin, more misclassifications)
# C=100 (strict margin, fewer violations, might overfit)
